# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# Let's import the required libraries

# %%
import pandas as pd
import numpy as np

import requests

from pandas.io.html import read_html

from sklearn.cluster import KMeans

import matplotlib.cm as cm
import matplotlib.colors as colors

from geopy.geocoders import Nominatim

import folium

print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ## 1. Download and Prepare the Dataset

# %% [markdown]
# The required data for segmenting and clustering neighborhoods in Toronto is not readily available. But, there is a source from the wikipedia with required informations that can be used.
#
# The link to the source is- https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# We have to scrape the data from this webpage and prepare it for further use.

# %% [markdown]
# We will be using pandas to scrape the data. Let's first prepare the given link to the webpage.

# %%
page = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

page
# Out:
# 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# Now, we will read the data from this page using the link and to acquire the table we tend to, we have to pass the following dictionary <span>{'class' : 'wikitable'}</span>
# to the attrs arguement in read_html function.
#
# Note: Tables in a wikipedia page has the class 'wikitable'.

# %%
wikitable = read_html(page, attrs={'class':'wikitable'})

print('Extracted table is {} type of length'.format(type(wikitable), len(wikitable)))
# Out:
# Extracted table is <class 'list'> type of length

# %% [markdown]
# Now, let's create a pandas data frame from the list type table.

# %%
df = pd.DataFrame(wikitable[0])

df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Let's get the shape of the data frame.

# %%
df.shape
# Out:
# (180, 3)

# %% [markdown]
# From the data frame we can see that there exists some postal codes which are not assigned to any Boroughs. Let's get rid of those rows.

# %%
new_df = df.drop(df.index[df['Borough'] == 'Not assigned'], axis = 0)

new_df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Now, let's check if there is any 'Neighbourhood' with the value 'Not assigned'

# %%
x = new_df.index[new_df.loc[:, 'Neighbourhood'] =='Not assigned']
len(x)
# Out:
# 0

# %% [markdown]
# There length of the list may be 0. If not, then let's set the values for those neighbourhoods same as their boroughs.

# %%
for i in x:
    new_df.loc[i, 'Neighbourhood'] = new_df.loc[i, 'Borough']

# %% [markdown]
# Now, let's reset the index of the data frame.

# %%
new_df = new_df.reset_index(drop=True)
new_df.head(10)
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 5         M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 6         M1B       Scarborough                               Malvern, Rouge
# 7         M3B        North York                                    Don Mills
# 8         M4B         East York              Parkview Hill, Woodbine Gardens
# 9         M5B  Downtown Toronto                     Garden District, Ryerson

# %% [markdown]
# Finally, let's print the shape of the final table.

# %% [markdown]
# ## Data Frame shape(1st Problem)

# %%
new_df.shape
# Out:
# (103, 3)

# %% [markdown]
# Now, let's get the location coordinates for each postal code.
#
# We'll read it from a csv file.

# %%
path = 'Geospatial_Coordinates.csv'

location_df = pd.read_csv(path)
location_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Now, let's merge the two data frames together into a single dataframe

# %% [markdown]
# ## Data Frame Created(2nd Problem)

# %%
toronto_df = new_df.merge(location_df, on=['Postal Code', 'Postal Code'])

toronto_df.head(12)
# Out:
#    Postal Code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                    Victoria Village  43.725882 -79.315572
# 2                           Regent Park, Harbourfront  43.654260 -79.360636
# 3                    Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 5             Islington Avenue, Humber Valley Village  43.667856 -79.532242
# 6                                      Malvern, Rouge  43.806686 -79.194353
# 7                                           Don Mills  43.745906 -79.352188
# 8                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 9                            Garden District, Ryerson  43.657162 -79.378937
# 10                                          Glencairn  43.709577 -79.445073
# 11  West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724

# %% [markdown]
# Now, check if the data frame is of the right shape.

# %%
toronto_df.shape
# Out:
# (103, 5)

# %% [markdown]
# Now, let's check how many borough and neighbourhood we are left with.

# %%
print('The dataframe has {} boroughs.'.format(
        len(toronto_df['Borough'].unique())
    )
)
# Out:
# The dataframe has 10 boroughs.

# %%
toronto_boroughs = toronto_df['Borough'].unique().tolist()

toronto_boroughs
# Out:
# ['North York',
#  'Downtown Toronto',
#  'Etobicoke',
#  'Scarborough',
#  'East York',
#  'York',
#  'East Toronto',
#  'West Toronto',
#  'Central Toronto',
#  'Mississauga']

# %% [markdown]
# __Use geopy library to get the latitude and longitude values of Toronto.__

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighbourhood in zip(toronto_df['Latitude'], toronto_df['Longitude'], toronto_df['Borough'], toronto_df['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, we will start using foresquare api to explore neighborhoods.

# %% [markdown]
# Let's define foresquare credentials.

# %%
LIMIT = 150

CLIENT_ID = 'QD5MIGEEOHFWRTVDFS0GANDCEDQYQYUM1GKT2Q1PPXX343QG'
CLIENT_SECRET = '2DUQMPPTBTRSI1FD1KBZ55XS4S4SLXWPPOVKFZ2ZUUWU1FW5'
VERSION = '20180605'

# %% [markdown]
# Now, let's get the 'getNearbyVenues' from previous lab to get the nearby venues of each neighbourhood.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        
        # extract the last neighbourhood where multiple neighbourhood exist for a single postal code
        #try:
        #    name = name.split(',')[-1].strip()
        #except:
        #    continue-->
        
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Now, let's get the nearby venues for each neighbourhood in different boroughs.

# %%
boroughwise_venues={}

for borough in toronto_boroughs:
    
    temp_df = toronto_df[toronto_df['Borough'] == borough] #data frame of the borough
    
    try:
        borough = borough.lower().replace(' ', '_') + '_venues'
    except:
        borough = borough + '_venues'
        
    boroughwise_venues[borough] = getNearbyVenues(names=temp_df['Neighbourhood'],
                                                  latitudes=temp_df['Latitude'],
                                                  longitudes=temp_df['Longitude']
                                  )
    
    print('{} acquired'.format(borough))
# Out:
# Parkwoods
# Victoria Village
# Lawrence Manor, Lawrence Heights
# Don Mills
# Glencairn
# Don Mills
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# Bayview Village
# Downsview
# York Mills, Silver Hills
# Downsview
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Willowdale, Newtonbrook
# Downsview
# Bedford Park, Lawrence Manor East
# Humberlea, Emery
# Willowdale, Willowdale East
# Downsview
# York Mills West
# Willowdale, Willowdale West
# north_york_venues acquired
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# downtown_toronto_venues acquired
# Islington Avenue, Humber Valley Village
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Westmount
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Alderwood, Long Branch
# Northwest, West Humber - Clairville
# The Kingsway, Montgomery Road, Old Mill North
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# etobicoke_venues acquired
# Malvern, Rouge
# Rouge Hill, Port Union, Highland Creek
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# Kennedy Park, Ionview, East Birchmount Park
# Golden Mile, Clairlea, Oakridge
# Cliffside, Cliffcrest, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Wexford Heights, Scarborough Town Centre
# Wexford, Maryvale
# Agincourt
# Clarks Corners, Tam O'Shanter, Sullivan
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Steeles West, L'Amoreaux West
# Upper Rouge
# scarborough_venues acquired
# Parkview Hill, Woodbine Gardens
# Woodbine Heights
# Leaside
# Thorncliffe Park
# East Toronto, Broadview North (Old East York)
# east_york_venues acquired
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Runnymede, The Junction North
# Weston
# york_venues acquired
# The Beaches
# The Danforth West, Riverdale
# India Bazaar, The Beaches West
# Studio District
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto
# east_toronto_venues acquired
# Dufferin, Dovercourt Village
# Little Portugal, Trinity
# Brockton, Parkdale Village, Exhibition Place
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# west_toronto_venues acquired
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Davisville
# Moore Park, Summerhill East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# central_toronto_venues acquired
# Canada Post Gateway Processing Centre
# mississauga_venues acquired

# %%
boroughwise_venues.keys()
# Out:
# dict_keys(['north_york_venues', 'downtown_toronto_venues', 'etobicoke_venues', 'scarborough_venues', 'east_york_venues', 'york_venues', 'east_toronto_venues', 'west_toronto_venues', 'central_toronto_venues', 'mississauga_venues'])

# %%
north_york_venues = boroughwise_venues['north_york_venues']
north_york_venues
# Out:
#                    Neighbourhood  Neighbourhood Latitude  \
# 0                      Parkwoods               43.753259
# 1                      Parkwoods               43.753259
# 2                      Parkwoods               43.753259
# 3               Victoria Village               43.725882
# 4               Victoria Village               43.725882
# ..                           ...                     ...
# 237  Willowdale, Willowdale West               43.782736
# 238  Willowdale, Willowdale West               43.782736
# 239  Willowdale, Willowdale West               43.782736
# 240  Willowdale, Willowdale West               43.782736
# 241  Willowdale, Willowdale West               43.782736
#
#      Neighbourhood Longitude                              Venue  \
# 0                 -79.329656                    Brookbanks Park
# 1                 -79.329656                      Variety Store
# 2                 -79.329656  Corrosion Service Company Limited
# 3                 -79.315572             Victoria Village Arena
# 4                 -79.315572                        Tim Hortons
# ..                       ...                                ...
# 237               -79.442259                 Shoppers Drug Mart
# 238               -79.442259                     RBC Royal Bank
# 239               -79.442259                        Tim Hortons
# 240               -79.442259                      Price Chopper
# 241               -79.442259                          Hartman's
#
#      Venue Latitude  Venue Longitude              Venue Category
# 0         43.751976       -79.332140                        Park
# 1         43.751974       -79.333114           Food & Drink Shop
# 2         43.752432       -79.334661  Construction & Landscaping
# 3         43.723481       -79.315635                Hockey Arena
# 4         43.725517       -79.313103                 Coffee Shop
# ..              ...              ...                         ...
# 237       43.784847       -79.446028                    Pharmacy
# 238       43.783894       -79.446603                        Bank
# 239       43.780940       -79.444231                 Coffee Shop
# 240       43.783237       -79.446339               Grocery Store
# 241       43.784312       -79.446213                     Butcher
#
# [242 rows x 7 columns]

# %%
north_york_venues.groupby('Neighbourhood').count()
# Out:
#                                                  Neighbourhood Latitude  \
# Neighbourhood
# Bathurst Manor, Wilson Heights, Downsview North                      22
# Bayview Village                                                       4
# Bedford Park, Lawrence Manor East                                    21
# Don Mills                                                            25
# Downsview                                                            16
# Fairview, Henry Farm, Oriole                                         65
# Glencairn                                                             6
# Hillcrest Village                                                     5
# Humber Summit                                                         2
# Humberlea, Emery                                                      1
# Lawrence Manor, Lawrence Heights                                     11
# North Park, Maple Leaf Park, Upwood Park                              6
# Northwood Park, York University                                       7
# Parkwoods                                                             3
# Victoria Village                                                      5
# Willowdale, Newtonbrook                                               1
# Willowdale, Willowdale East                                          33
# Willowdale, Willowdale West                                           6
# York Mills West                                                       2
# York Mills, Silver Hills                                              1
#
#                                                  Neighbourhood Longitude  \
# Neighbourhood
# Bathurst Manor, Wilson Heights, Downsview North                       22
# Bayview Village                                                        4
# Bedford Park, Lawrence Manor East                                     21
# Don Mills                                                             25
# Downsview                                                             16
# Fairview, Henry Farm, Oriole                                          65
# Glencairn                                                              6
# Hillcrest Village                                                      5
# Humber Summit                                                          2
# Humberlea, Emery                                                       1
# Lawrence Manor, Lawrence Heights                                      11
# North Park, Maple Leaf Park, Upwood Park                               6
# Northwood Park, York University                                        7
# Parkwoods                                                              3
# Victoria Village                                                       5
# Willowdale, Newtonbrook                                                1
# Willowdale, Willowdale East                                           33
# Willowdale, Willowdale West                                            6
# York Mills West                                                        2
# York Mills, Silver Hills                                               1
#
#                                                  Venue  Venue Latitude  \
# Neighbourhood
# Bathurst Manor, Wilson Heights, Downsview North     22              22
# Bayview Village                                      4               4
# Bedford Park, Lawrence Manor East                   21              21
# Don Mills                                           25              25
# Downsview                                           16              16
# Fairview, Henry Farm, Oriole                        65              65
# Glencairn                                            6               6
# Hillcrest Village                                    5               5
# Humber Summit                                        2               2
# Humberlea, Emery                                     1               1
# Lawrence Manor, Lawrence Heights                    11              11
# North Park, Maple Leaf Park, Upwood Park             6               6
# Northwood Park, York University                      7               7
# Parkwoods                                            3               3
# Victoria Village                                     5               5
# Willowdale, Newtonbrook                              1               1
# Willowdale, Willowdale East                         33              33
# Willowdale, Willowdale West                          6               6
# York Mills West                                      2               2
# York Mills, Silver Hills                             1               1
#
#                                                  Venue Longitude  \
# Neighbourhood
# Bathurst Manor, Wilson Heights, Downsview North               22
# Bayview Village                                                4
# Bedford Park, Lawrence Manor East                             21
# Don Mills                                                     25
# Downsview                                                     16
# Fairview, Henry Farm, Oriole                                  65
# Glencairn                                                      6
# Hillcrest Village                                              5
# Humber Summit                                                  2
# Humberlea, Emery                                               1
# Lawrence Manor, Lawrence Heights                              11
# North Park, Maple Leaf Park, Upwood Park                       6
# Northwood Park, York University                                7
# Parkwoods                                                      3
# Victoria Village                                               5
# Willowdale, Newtonbrook                                        1
# Willowdale, Willowdale East                                   33
# Willowdale, Willowdale West                                    6
# York Mills West                                                2
# York Mills, Silver Hills                                       1
#
#                                                  Venue Category
# Neighbourhood
# Bathurst Manor, Wilson Heights, Downsview North              22
# Bayview Village                                               4
# Bedford Park, Lawrence Manor East                            21
# Don Mills                                                    25
# Downsview                                                    16
# Fairview, Henry Farm, Oriole                                 65
# Glencairn                                                     6
# Hillcrest Village                                             5
# Humber Summit                                                 2
# Humberlea, Emery                                              1
# Lawrence Manor, Lawrence Heights                             11
# North Park, Maple Leaf Park, Upwood Park                      6
# Northwood Park, York University                               7
# Parkwoods                                                     3
# Victoria Village                                              5
# Willowdale, Newtonbrook                                       1
# Willowdale, Willowdale East                                  33
# Willowdale, Willowdale West                                   6
# York Mills West                                               2
# York Mills, Silver Hills                                      1

# %%
print('There are {} uniques categories.'.format(len(north_york_venues['Venue Category'].unique())))
# Out:
# There are 104 uniques categories.

# %% [markdown]
# ## 2. Analyzing Neighbourhoods

# %% [markdown]
# One hot encoding is needed to feed the data into clustering algorithm.
#
# Let's do one hot encoding to all the neighbourhoods.

# %%
borough_grouped = {}
for borough_venues in boroughwise_venues.keys():
    temp_venues = boroughwise_venues[borough_venues]
    # one hot encoding
    temp_onehot = pd.get_dummies(temp_venues[['Venue Category']], prefix="", prefix_sep="")

    # add neighborhood column back to dataframe
    temp_onehot['Neighbourhood'] = temp_venues['Neighbourhood'] 

    # move neighborhood column to the first column
    fixed_columns = [temp_onehot.columns[-1]] + list(temp_onehot.columns[:-1])
    temp_onehot = temp_onehot[fixed_columns]
    
    temp_grouped = temp_onehot.groupby('Neighbourhood').mean().reset_index()

    borough_grouped[borough_venues+'_grouped'] = temp_grouped

# %%
borough_grouped.keys()
# Out:
# dict_keys(['north_york_venues_grouped', 'downtown_toronto_venues_grouped', 'etobicoke_venues_grouped', 'scarborough_venues_grouped', 'east_york_venues_grouped', 'york_venues_grouped', 'east_toronto_venues_grouped', 'west_toronto_venues_grouped', 'central_toronto_venues_grouped', 'mississauga_venues_grouped'])

# %%
north_york_venues_grouped = borough_grouped['north_york_venues_grouped']

north_york_venues_grouped.head()
north_york_venues_grouped.shape
# Out:
# (20, 105)

# %% [markdown]
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = north_york_venues_grouped['Neighbourhood']

for ind in np.arange(north_york_venues_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(north_york_venues_grouped.iloc[ind, :], num_top_venues)
    

neighbourhoods_venues_sorted
# Out:
#                                       Neighbourhood 1st Most Common Venue  \
# 0   Bathurst Manor, Wilson Heights, Downsview North           Coffee Shop
# 1                                   Bayview Village    Chinese Restaurant
# 2                 Bedford Park, Lawrence Manor East        Sandwich Place
# 3                                         Don Mills                   Gym
# 4                                         Downsview                  Park
# 5                      Fairview, Henry Farm, Oriole        Clothing Store
# 6                                         Glencairn           Pizza Place
# 7                                 Hillcrest Village           Golf Course
# 8                                     Humber Summit           Pizza Place
# 9                                  Humberlea, Emery        Baseball Field
# 10                 Lawrence Manor, Lawrence Heights        Clothing Store
# 11         North Park, Maple Leaf Park, Upwood Park                 Trail
# 12                  Northwood Park, York University           Coffee Shop
# 13                                        Parkwoods                  Park
# 14                                 Victoria Village           Pizza Place
# 15                          Willowdale, Newtonbrook                  Park
# 16                      Willowdale, Willowdale East      Ramen Restaurant
# 17                      Willowdale, Willowdale West              Pharmacy
# 18                                  York Mills West                  Park
# 19                         York Mills, Silver Hills             Cafeteria
#
#          2nd Most Common Venue       3rd Most Common Venue  \
# 0                         Bank                       Diner
# 1                         Café                        Bank
# 2           Italian Restaurant                 Coffee Shop
# 3                  Coffee Shop            Asian Restaurant
# 4                Grocery Store                  Food Truck
# 5                  Coffee Shop        Fast Food Restaurant
# 6                Metro Station            Asian Restaurant
# 7                         Pool          Athletics & Sports
# 8                 Home Service               Women's Store
# 9                Women's Store              Discount Store
# 10           Accessories Store      Furniture / Home Store
# 11  Construction & Landscaping                      Bakery
# 12      Furniture / Home Store        Caribbean Restaurant
# 13           Food & Drink Shop  Construction & Landscaping
# 14                 Coffee Shop                Hockey Arena
# 15               Women's Store                 Golf Course
# 16              Sandwich Place                        Café
# 17               Grocery Store                 Pizza Place
# 18           Convenience Store               Women's Store
# 19               Women's Store              Chocolate Shop
#
#        4th Most Common Venue    5th Most Common Venue  \
# 0                       Park              Pizza Place
# 1        Japanese Restaurant                    Diner
# 2           Greek Restaurant            Grocery Store
# 3        Japanese Restaurant               Restaurant
# 4             Baseball Field           Discount Store
# 5                 Restaurant                     Bank
# 6           Sushi Restaurant                      Pub
# 7   Mediterranean Restaurant                  Dog Run
# 8                      Diner           Clothing Store
# 9                Coffee Shop  Comfort Food Restaurant
# 10               Event Space              Coffee Shop
# 11             Deli / Bodega         Basketball Court
# 12        Miscellaneous Shop       Falafel Restaurant
# 13             Women's Store       Dim Sum Restaurant
# 14     Portuguese Restaurant             Intersection
# 15            Clothing Store              Coffee Shop
# 16       Japanese Restaurant              Coffee Shop
# 17               Coffee Shop                  Butcher
# 18               Golf Course           Clothing Store
# 19               Coffee Shop  Comfort Food Restaurant
#
#          6th Most Common Venue       7th Most Common Venue  \
# 0                  Bridal Shop              Ice Cream Shop
# 1                  Coffee Shop     Comfort Food Restaurant
# 2            Indian Restaurant                   Juice Bar
# 3                   Beer Store              Discount Store
# 4                   Playground               Shopping Mall
# 5                       Bakery          Chinese Restaurant
# 6          Japanese Restaurant               Women's Store
# 7                Women's Store          Dim Sum Restaurant
# 8                  Coffee Shop     Comfort Food Restaurant
# 9   Construction & Landscaping           Convenience Store
# 10                    Boutique       Vietnamese Restaurant
# 11                        Park               Women's Store
# 12                         Bar              Massage Studio
# 13              Clothing Store                 Coffee Shop
# 14               Women's Store          Dim Sum Restaurant
# 15     Comfort Food Restaurant  Construction & Landscaping
# 16                 Pizza Place                  Restaurant
# 17                        Bank          Dim Sum Restaurant
# 18                 Coffee Shop     Comfort Food Restaurant
# 19  Construction & Landscaping           Convenience Store
#
#          8th Most Common Venue      9th Most Common Venue  \
# 0                Deli / Bodega                 Restaurant
# 1   Construction & Landscaping          Convenience Store
# 2                 Liquor Store    Comfort Food Restaurant
# 3               Clothing Store         Chinese Restaurant
# 4                        Hotel               Home Service
# 5          Japanese Restaurant                  Juice Bar
# 6                 Dessert Shop             Clothing Store
# 7                  Coffee Shop    Comfort Food Restaurant
# 8   Construction & Landscaping          Convenience Store
# 9               Cosmetics Shop              Deli / Bodega
# 10           Food & Drink Shop       Fast Food Restaurant
# 11                       Diner             Clothing Store
# 12          Dim Sum Restaurant    Comfort Food Restaurant
# 13     Comfort Food Restaurant          Convenience Store
# 14              Clothing Store    Comfort Food Restaurant
# 15           Convenience Store             Cosmetics Shop
# 16                   Juice Bar  Middle Eastern Restaurant
# 17              Clothing Store    Comfort Food Restaurant
# 18  Construction & Landscaping             Cosmetics Shop
# 19              Cosmetics Shop              Deli / Bodega
#
#         10th Most Common Venue
# 0                     Pharmacy
# 1               Cosmetics Shop
# 2                         Café
# 3         Caribbean Restaurant
# 4             Business Service
# 5                   Shoe Store
# 6                  Coffee Shop
# 7   Construction & Landscaping
# 8               Cosmetics Shop
# 9             Department Store
# 10                 Gas Station
# 11                 Coffee Shop
# 12  Construction & Landscaping
# 13              Cosmetics Shop
# 14  Construction & Landscaping
# 15               Deli / Bodega
# 16               Movie Theater
# 17  Construction & Landscaping
# 18               Deli / Bodega
# 19            Department Store

# %% [markdown]
# ## 3. Cluster Neighborhoods

# %% [markdown]
# Now, let's do k-means clustering to this North York Dataset

# %%
# set number of clusters
kclusters = 3

north_york_venues_grouped_clustering = north_york_venues_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(north_york_venues_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_.shape
# Out:
# (20,)

# %%
# add clustering labels
neighbourhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
north_york_venues_merged = toronto_df[toronto_df['Borough'] == 'North York'].reset_index(drop=True)
# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
north_york_venues_merged = north_york_venues_merged.merge(neighbourhoods_venues_sorted, on=['Neighbourhood', 'Neighbourhood'])

north_york_venues_merged.head() # check the last columns!
# Out:
#   Postal Code     Borough                     Neighbourhood   Latitude  \
# 0         M3A  North York                         Parkwoods  43.753259
# 1         M4A  North York                  Victoria Village  43.725882
# 2         M6A  North York  Lawrence Manor, Lawrence Heights  43.718518
# 3         M3B  North York                         Don Mills  43.745906
# 4         M3C  North York                         Don Mills  43.725900
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.329656               0                  Park     Food & Drink Shop
# 1 -79.315572               2           Pizza Place           Coffee Shop
# 2 -79.464763               2        Clothing Store     Accessories Store
# 3 -79.352188               2                   Gym           Coffee Shop
# 4 -79.340923               2                   Gym           Coffee Shop
#
#         3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 0  Construction & Landscaping          Women's Store    Dim Sum Restaurant
# 1                Hockey Arena  Portuguese Restaurant          Intersection
# 2      Furniture / Home Store            Event Space           Coffee Shop
# 3            Asian Restaurant    Japanese Restaurant            Restaurant
# 4            Asian Restaurant    Japanese Restaurant            Restaurant
#
#   6th Most Common Venue  7th Most Common Venue    8th Most Common Venue  \
# 0        Clothing Store            Coffee Shop  Comfort Food Restaurant
# 1         Women's Store     Dim Sum Restaurant           Clothing Store
# 2              Boutique  Vietnamese Restaurant        Food & Drink Shop
# 3            Beer Store         Discount Store           Clothing Store
# 4            Beer Store         Discount Store           Clothing Store
#
#      9th Most Common Venue      10th Most Common Venue
# 0        Convenience Store              Cosmetics Shop
# 1  Comfort Food Restaurant  Construction & Landscaping
# 2     Fast Food Restaurant                 Gas Station
# 3       Chinese Restaurant        Caribbean Restaurant
# 4       Chinese Restaurant        Caribbean Restaurant

# %%
address = 'North York, ON'

geolocator = Nominatim(user_agent="foresquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(north_york_venues_merged['Latitude'], north_york_venues_merged['Longitude'], north_york_venues_merged['Neighbourhood'], north_york_venues_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# The geograpical coordinate of Manhattan are 43.7543263, -79.44911696639593.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4. Examine the clusters

# %% [markdown]
# __Cluster 1__

# %%
north_york_venues_merged.loc[north_york_venues_merged['Cluster Labels'] == 0, north_york_venues_merged.columns[[2] + list(range(6, north_york_venues_merged.shape[1]))]]
# Out:
#               Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 0                 Parkwoods                  Park     Food & Drink Shop
# 18  Willowdale, Newtonbrook                  Park         Women's Store
# 22          York Mills West                  Park     Convenience Store
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0   Construction & Landscaping         Women's Store    Dim Sum Restaurant
# 18                 Golf Course        Clothing Store           Coffee Shop
# 22               Women's Store           Golf Course        Clothing Store
#
#       6th Most Common Venue       7th Most Common Venue  \
# 0            Clothing Store                 Coffee Shop
# 18  Comfort Food Restaurant  Construction & Landscaping
# 22              Coffee Shop     Comfort Food Restaurant
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0      Comfort Food Restaurant     Convenience Store         Cosmetics Shop
# 18           Convenience Store        Cosmetics Shop          Deli / Bodega
# 22  Construction & Landscaping        Cosmetics Shop          Deli / Bodega

# %% [markdown]
# __Cluster 2__

# %%
north_york_venues_merged.loc[north_york_venues_merged['Cluster Labels'] == 1, north_york_venues_merged.columns[[2] + list(range(6, north_york_venues_merged.shape[1]))]]
# Out:
#                Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 15  York Mills, Silver Hills             Cafeteria         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue    5th Most Common Venue  \
# 15        Chocolate Shop           Coffee Shop  Comfort Food Restaurant
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 15  Construction & Landscaping     Convenience Store        Cosmetics Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 15         Deli / Bodega       Department Store

# %% [markdown]
# __Cluster 3__

# %%
north_york_venues_merged.loc[north_york_venues_merged['Cluster Labels'] == 2, north_york_venues_merged.columns[[2] + list(range(6, north_york_venues_merged.shape[1]))]]
# Out:
#                                       Neighbourhood 1st Most Common Venue  \
# 1                                  Victoria Village           Pizza Place
# 2                  Lawrence Manor, Lawrence Heights        Clothing Store
# 3                                         Don Mills                   Gym
# 4                                         Don Mills                   Gym
# 5                                         Glencairn           Pizza Place
# 6                                 Hillcrest Village           Golf Course
# 7   Bathurst Manor, Wilson Heights, Downsview North           Coffee Shop
# 8                      Fairview, Henry Farm, Oriole        Clothing Store
# 9                   Northwood Park, York University           Coffee Shop
# 10                                  Bayview Village    Chinese Restaurant
# 11                                        Downsview                  Park
# 12                                        Downsview                  Park
# 13                                        Downsview                  Park
# 14                                        Downsview                  Park
# 16         North Park, Maple Leaf Park, Upwood Park                 Trail
# 17                                    Humber Summit           Pizza Place
# 19                Bedford Park, Lawrence Manor East        Sandwich Place
# 20                                 Humberlea, Emery        Baseball Field
# 21                      Willowdale, Willowdale East      Ramen Restaurant
# 23                      Willowdale, Willowdale West              Pharmacy
#
#          2nd Most Common Venue   3rd Most Common Venue  \
# 1                  Coffee Shop            Hockey Arena
# 2            Accessories Store  Furniture / Home Store
# 3                  Coffee Shop        Asian Restaurant
# 4                  Coffee Shop        Asian Restaurant
# 5                Metro Station        Asian Restaurant
# 6                         Pool      Athletics & Sports
# 7                         Bank                   Diner
# 8                  Coffee Shop    Fast Food Restaurant
# 9       Furniture / Home Store    Caribbean Restaurant
# 10                        Café                    Bank
# 11               Grocery Store              Food Truck
# 12               Grocery Store              Food Truck
# 13               Grocery Store              Food Truck
# 14               Grocery Store              Food Truck
# 16  Construction & Landscaping                  Bakery
# 17                Home Service           Women's Store
# 19          Italian Restaurant             Coffee Shop
# 20               Women's Store          Discount Store
# 21              Sandwich Place                    Café
# 23               Grocery Store             Pizza Place
#
#        4th Most Common Venue    5th Most Common Venue  \
# 1      Portuguese Restaurant             Intersection
# 2                Event Space              Coffee Shop
# 3        Japanese Restaurant               Restaurant
# 4        Japanese Restaurant               Restaurant
# 5           Sushi Restaurant                      Pub
# 6   Mediterranean Restaurant                  Dog Run
# 7                       Park              Pizza Place
# 8                 Restaurant                     Bank
# 9         Miscellaneous Shop       Falafel Restaurant
# 10       Japanese Restaurant                    Diner
# 11            Baseball Field           Discount Store
# 12            Baseball Field           Discount Store
# 13            Baseball Field           Discount Store
# 14            Baseball Field           Discount Store
# 16             Deli / Bodega         Basketball Court
# 17                     Diner           Clothing Store
# 19          Greek Restaurant            Grocery Store
# 20               Coffee Shop  Comfort Food Restaurant
# 21       Japanese Restaurant              Coffee Shop
# 23               Coffee Shop                  Butcher
#
#          6th Most Common Venue    7th Most Common Venue  \
# 1                Women's Store       Dim Sum Restaurant
# 2                     Boutique    Vietnamese Restaurant
# 3                   Beer Store           Discount Store
# 4                   Beer Store           Discount Store
# 5          Japanese Restaurant            Women's Store
# 6                Women's Store       Dim Sum Restaurant
# 7                  Bridal Shop           Ice Cream Shop
# 8                       Bakery       Chinese Restaurant
# 9                          Bar           Massage Studio
# 10                 Coffee Shop  Comfort Food Restaurant
# 11                  Playground            Shopping Mall
# 12                  Playground            Shopping Mall
# 13                  Playground            Shopping Mall
# 14                  Playground            Shopping Mall
# 16                        Park            Women's Store
# 17                 Coffee Shop  Comfort Food Restaurant
# 19           Indian Restaurant                Juice Bar
# 20  Construction & Landscaping        Convenience Store
# 21                 Pizza Place               Restaurant
# 23                        Bank       Dim Sum Restaurant
#
#          8th Most Common Venue      9th Most Common Venue  \
# 1               Clothing Store    Comfort Food Restaurant
# 2            Food & Drink Shop       Fast Food Restaurant
# 3               Clothing Store         Chinese Restaurant
# 4               Clothing Store         Chinese Restaurant
# 5                 Dessert Shop             Clothing Store
# 6                  Coffee Shop    Comfort Food Restaurant
# 7                Deli / Bodega                 Restaurant
# 8          Japanese Restaurant                  Juice Bar
# 9           Dim Sum Restaurant    Comfort Food Restaurant
# 10  Construction & Landscaping          Convenience Store
# 11                       Hotel               Home Service
# 12                       Hotel               Home Service
# 13                       Hotel               Home Service
# 14                       Hotel               Home Service
# 16                       Diner             Clothing Store
# 17  Construction & Landscaping          Convenience Store
# 19                Liquor Store    Comfort Food Restaurant
# 20              Cosmetics Shop              Deli / Bodega
# 21                   Juice Bar  Middle Eastern Restaurant
# 23              Clothing Store    Comfort Food Restaurant
#
#         10th Most Common Venue
# 1   Construction & Landscaping
# 2                  Gas Station
# 3         Caribbean Restaurant
# 4         Caribbean Restaurant
# 5                  Coffee Shop
# 6   Construction & Landscaping
# 7                     Pharmacy
# 8                   Shoe Store
# 9   Construction & Landscaping
# 10              Cosmetics Shop
# 11            Business Service
# 12            Business Service
# 13            Business Service
# 14            Business Service
# 16                 Coffee Shop
# 17              Cosmetics Shop
# 19                        Café
# 20            Department Store
# 21               Movie Theater
# 23  Construction & Landscaping

# %% [markdown]
# __As the data are prepared we can now segment and cluster data from any borough to analyze neighbourhood.__
